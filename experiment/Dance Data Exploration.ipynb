# %%
import os, pathlib, json
import numpy as np
from pathlib import Path

# %%
ROOT_DIR = "../densepose/txt/"
CATEGORIES = os.listdir(ROOT_DIR)
FRAME_DESCRIPTOR_LENGTH = len("_1234.json")

# %%
def filename_to_id(filename):
    return filename[0:-FRAME_DESCRIPTOR_LENGTH]

# %%
def filename_to_frame_no(filename):
    # lWfg9CNg-uE_123_FRAMENO.json
    # Split on _ -> [lWfg9CNg-uE, 123, FRAMENO.json]
    # Get last element, and then read convert FRAMENO to int
    return int(filename.split("_")[-1].split(".")[0])

# %%
index = {}
for category in CATEGORIES:
    DANCE_DIR = "{}{}/".format(ROOT_DIR, category)
    filenames = os.listdir(DANCE_DIR)
    filenames.sort()
    for filename in filenames:
        if category not in index:
            index[category] = {}
        dance_id = filename_to_id(filename)
        frame = filename_to_frame_no(filename)
        if dance_id not in index[category]:
            index[category][dance_id] = [1, -1]
        index[category][dance_id][1] = frame

# %%
# Out:
# {'tango': {'-638J1hhteA_019': [1, 301],
#   '0-pUvBqZ9PY_105': [1, 301],
#   '1yYiYMNxza8_012': [1, 301],
#   '3zCT36UnEcA_220': [1, 301],
#   '4ZKupt7FxRE_009': [1, 301],
#   '4flyoSPVlHI_028': [1, 301],
#   '5LxiCFVBuSI_027': [1, 301],
#   '8LMvAf5ftZ4_008': [1, 301],
#   '8p6MyuvAebg_013': [1, 301],
#   'AQ7HEnCtnJg_012': [1, 301],
#   'AVaxGhMgHMk_018': [1, 301],
#   'AXhCzjiIqRA_043': [1, 301],
#   'Ap9Xj0OBgJ8_043': [1, 301],
#   'BCIqkUblDpM_026': [1, 241],
#   'BvTGEgR2_88_025': [1, 301],
#   'DOSiIbjykc4_020': [1, 301],
#   'DuX-R1KgEck_208': [1, 301],
#   'ETcDfLqzyHE_010': [1, 301],
#   'EjvOhPft9ZU_010': [1, 301],
#   'FY0I_ppROdc_008': [1, 301],
#   'GvyTlvSShv4_034': [1, 301],
#   'HJyQjQy9n-U_158': [1, 301],
#   'HdMS4Bmon5I_009': [1, 301],
#   'IVj4Aq-pkIg_010': [1, 301],
#   'L9aELK-wh0I_033': [1, 301],
#   'LtCyhGvWUe4_039': [1, 301],
#   'MDmXbagFW6o_043': [1, 301],
#   'MIgs0QVQhkE_020': [1, 301],
#   'MZ1tmTqt1Kk_031': [1, 301],
#   'NQZKq-qnbGw_006': [1, 301],
#   'NVtD7I_iKL8_020': [1, 301],
#   'Nb0iHhNtX38_009': [1, 301],
#   'O-VqF4iKyLQ_105': [1, 301],
#   'PewFkC3wcL4_033': [1, 301],
#   'QpXrvqsD67s_020': [1, 301],
#   'RDAGP168lns_017': [1, 301],
#   'RQpaRC_McSI_216': [1, 301],
#   'SuggIS57QRE_005': [1, 301],
#   'SzWNayeS-K8_009': [1, 301],
#   'UMjKb1ckHGI_009': [1, 301],
#   'UVgjpKAaufk_036': [1, 301],
#   'UlgGleFjrMo_059': [1, 301],
#   'W5WlHF9ZvIc_049': [1, 301],
#   'Wh7yyIaI2XI_126': [1, 301],
#   'ZSdLqCZ5WJo_040': [1, 301],
#   'ZcmjLdmkQxY_214': [1, 301],
#   '_McT_YK1WYM_039': [1, 301],
#   'b67jXhRbmh0_030': [1, 301],
#   'bFFMIYUEDq4_039': [1, 301],
#   'bFH668_otBg_114': [1, 301],
#   'bHVTOfyVfFU_019': [1, 301],
#   'dVqPqFBZoXI_009': [1, 301],
#   'dkZigQYTUJo_044': [1, 301],
#   'e8L1YmW25zY_025': [1, 301],
#   'fI1K8QObgp0_106': [1, 301],
#   'f_B1okk4iIo_033': [1, 301],
#   'gTFiW8cDBMk_015': [1, 301],
#   'gu43cNIDyDc_019': [1, 301],
#   'jY2osKpEi4A_018': [1, 301],
#   'jz3L-OlPWoA_042': [1, 301],
#   'kWb6u32vK7A_020': [1, 301],
#   'ka6Z7PXVrSM_109': [1, 301],
#   'lNqHYRVPyds_100': [1, 301],
#   'mBt-cEgqPwc_410': [1, 301],
#   'nIs58c02l_s_014': [1, 301],
#   'oAim7ILCZTw_115': [1, 301],
#   'r1AEsFzZYQw_056': [1, 301],
#   's1FBlGyv4TU_051': [1, 301],
#   'sRAgy-3S9BY_216': [1, 301],
#   'tW6H80y8JgY_019': [1, 301],
#   'uQ1o81nYonI_004': [1, 301],
#   'uiAsItFDBsk_300': [1, 301],
#   'v2Wx2pk2blU_013': [1, 301],
#   'wgrUL5Gqj7M_009': [1, 301],
#   'wgrUL5Gqj7M_044': [1, 301],
#   'wgrUL5Gqj7M_109': [1, 301],
#   'yBogGeFGunE_047': [1, 301],
#   'yfzpR25btwM_113': [1, 301],
#   'zcu75HUX4Bg_020': [1, 301],
#   'zoqVTbEYS9o_039': [1, 301]},
#  'break': {'-kT0HJhm5ck_039': [1, 241],
#   '29LWQBYKZIQ_341': [1, 251],
#   '2VyZmSnD27Y_041': [1, 241],
#   '2oRysW2mm4A_010': [1, 301],
#   '2oRysW2mm4A_016': [1, 301],
#   '44kKLeDKIIc_110': [1, 301],
#   '4OEuiJX-Syg_039': [1, 301],
#   '4SQVm2fyLH0_053': [1, 251],
#   '4e1xHY9BO8o_041': [1, 251],
#   '4vwDZl4uxK0_141': [1, 301],
#   '5Dip4XeTysw_022': [1, 251],
#   '6dbo5GtNnxU_144': [1, 301],
#   '7NQvL_fUziU_043': [1, 301],
#   '7eonD7CQs00_047': [1, 251],
#   '7iKC-e_YAVk_040': [1, 251],
#   '7t-aIKgHCoI_302': [1, 251],
#   '8X_PJ0KXC0E_021': [1, 251],
#   '9j5UmA58qbw_208': [1, 251],
#   'BLJLTZEXym4_030': [1, 241],
#   'BXWFFGejC1E_030': [1, 251],
#   'Cg-5lC_KS98_050': [1, 251],
#   'DC37C6TcYe8_040': [1, 301],
#   'De3p-KyB9OI_059': [1, 251],
#   'Df-zWhQhC50_048': [1, 241],
#   'FgH6ZEhKZaQ_143': [1, 151],
#   'GgeiNsyYTAA_100': [1, 251],
#   'HZSi4E0452c_049': [1, 251],
#   'IaZEGDiQeCw_025': [1, 301],
#   'IzgPV9TpX64_139': [1, 251],
#   'J4_V3Q1LZvQ_037': [1, 241],
#   'J5s1ZJXkarw_018': [1, 301],
#   'J9Yo2Zpl_HE_033': [1, 241],
#   'Lg4jKPVgNEc_121': [1, 241],
#   'MDzsZxSj0mk_125': [1, 241],
#   'Mc_-bckuHNY_045': [1, 301],
#   'N5Qu7t4Mb4I_053': [1, 301],
#   'NFzJyJXWkeU_100': [1, 301],
#   'NV-1pERNBjE_112': [1, 251],
#   'NsrYSHQnZDI_046': [1, 296],
#   'P17nzRf6HiE_020': [1, 241],
#   'PAtczoSampg_101': [1, 301],
#   'PlVIMP5iRdY_011': [1, 301],
#   'Pm4-T2xhY1c_110': [1, 251],
#   'Pog_fSYfl7M_032': [1, 301],
#   'PxY5dC9vfxg_030': [1, 241],
#   'RIbH_mQ4YGM_037': [1, 251],
#   'RJnOuAf0cEY_025': [1, 301],
#   'S7tQIPMejL8_027': [1, 251],
#   'SYUbP0hDB3k_054': [1, 301],
#   'SpKPsgvW6HA_026': [1, 301],
#   'SxMRYmSKr8w_016': [1, 241],
#   'T0Hxyi-QPPE_123': [1, 301],
#   'T7ns0dDc6Bs_100': [1, 301],
#   'ToFyPVocxMk_037': [1, 301],
#   'UBdYHMxMgiw_022': [1, 251],
#   'V3lWySwbP1E_035': [1, 113],
#   'XnapRl2hHTo_050': [1, 301],
#   'Xt3Ce6RnZRM_024': [1, 251],
#   'Xw-VKan4ypA_132': [1, 301],
#   '_UzMJuR1T0w_012': [1, 241],
#   '_eqF-TA8TVQ_043': [1, 301],
#   '_rHO5g9KPyI_020': [1, 251],
#   'a9x8Zq6an24_058': [1, 301],
#   'bmcemnynJuU_105': [1, 251],
#   'cEDSBE0hZGU_025': [1, 241],
#   'dNVSVlow_a4_152': [1, 251],
#   'gd_49P1NUoU_019': [1, 251],
#   'hAhQLB2XzRo_035': [1, 241],
#   'hY8de4NKa0s_059': [1, 301],
#   'iITT9FT_Jn4_129': [1, 251],
#   'jLPo2BIigZg_036': [1, 301],
#   'k2yuhqz_Tmg_046': [1, 251],
#   'mJPtjZp14DU_029': [1, 251],
#   'nF-1issipwU_144': [1, 251],
#   'ndUDTMBzJmU_020': [1, 301],
#   'njw1rxDmUU0_025': [1, 301],
#   'ntPreFTiNXQ_030': [1, 301],
#   'pRqAWBtaJzI_219': [1, 301],
#   'qO6w2KYuwOg_101': [1, 300],
#   'qpdQLbp-7nQ_300': [1, 301],
#   'rLC2c-_uWjg_029': [1, 301],
#   'rnNe34i8sXU_116': [1, 241],
#   'rnNe34i8sXU_133': [1, 241],
#   'tbFKZGzX9Kg_103': [1, 226],
#   'uY-CG6YmEkw_046': [1, 251],
#   'v_XbJRPzlAQ_253': [1, 251],
#   'vf5VISl5XzQ_127': [1, 301],
#   'wJ-f773sO-k_040': [1, 241],
#   'wPXxHyViTW0_040': [1, 251],
#   'wTrDn7Mj4MU_043': [1, 241],
#   'xM2accUWanU_043': [1, 251],
#   'xpTKbQ32qdQ_034': [1, 301],
#   'y6kboFhoxow_106': [1, 602],
#   'ybEnwLTtz9g_118': [1, 301],
#   'yimGp0XUcEE_150': [1, 176]},
#  'swing': {'0FYfWsrSORc_030': [1, 301],
#   '1XRNi8vFf5c_115': [1, 251],
#   '3eYSQmsVfbI_007': [1, 241],
#   '4tHDQQSvI_U_010': [1, 301],
#   '5Q3JjTE-qYE_050': [1, 301],
#   '5rixNuydqj4_115': [1, 251],
#   '6Wql41XtOzE_026': [1, 301],
#   '6ih6GNNym-U_028': [1, 251],
#   '7O6kPEPOoaE_216': [1, 241],
#   '7nuVb64HyT0_048': [1, 301],
#   '8DwU6-M_FsY_040': [1, 241],
#   '8KD_wWqWdf4_055': [1, 301],
#   '8aC4D_IaxHw_019': [1, 251],
#   '8l5pczCZw04_033': [1, 301],
#   '90CAxcl0CGY_105': [1, 301],
#   '9GTrNLauLrs_019': [1, 241],
#   'AehnnJzWO80_103': [1, 251],
#   'Am1z2_BW_kc_203': [1, 251],
#   'BDv7NhMjhg4_435': [1, 301],
#   'DILm3W8IhEg_024': [1, 251],
#   'DoAIhu_3XR0_045': [1, 301],
#   'EO4vRdWKPqE_033': [1, 301],
#   'FunRvh1OFBY_038': [1, 251],
#   'GGD7O_S3CRQ_020': [1, 301],
#   'HLCpqxrPmz8_020': [1, 301],
#   'HP_DW9LjcDk_039': [1, 301],
#   'HXKqQWy3NMY_105': [1, 301],
#   'HtXSPYEiKCY_037': [1, 301],
#   'IVaRyjtSNnc_032': [1, 251],
#   'Jn8DUhMUcyY_036': [1, 301],
#   'KnCVeiz9p3I_033': [1, 301],
#   'NNMnfTyc4Vg_029': [1, 241],
#   'NjWQgLsyggI_035': [1, 251],
#   'Npe8Vv_YH3Q_020': [1, 301],
#   'O65KqT0Vby8_205': [1, 301],
#   'QxrwmyiOYLQ_020': [1, 301],
#   'R-SzOoLlaj0_039': [1, 301],
#   'RVMO1PKHi4k_500': [1, 241],
#   'RmMkV2yPKAs_033': [1, 241],
#   'Rwg_OJEDm7g_028': [1, 301],
#   'SjRsHRnnyEg_046': [1, 251],
#   'SxMxOa22PlM_050': [1, 251],
#   'ToOYmxoA0Fg_025': [1, 251],
#   'UY9pmRFPpbE_026': [1, 251],
#   'V21PEmv_8yY_029': [1, 301],
#   'W38-MfFBQ3Y_030': [1, 301],
#   'WwJ5TtGmp7Y_016': [1, 301],
#   'XAnPQz21pZA_308': [1, 241],
#   'ZP-ed0LaklU_115': [1, 251],
#   'ZVDnzh7qVMQ_027': [1, 301],
#   'Zh6Dy9RaBeQ_015': [1, 301],
#   '_FidGI7J718_039': [1, 241],
#   'aS5DvL8p4I4_011': [1, 301],
#   'azjibU7_4z4_045': [1, 301],
#   'b0bKMpMsCTE_104': [1, 241],
#   'bl3s6PORZf0_130': [1, 251],
#   'c4XT7yVeSSo_016': [1, 204],
#   'dRQ-RsAXdEM_020': [1, 299],
#   'e62p_K4-Cvc_028': [1, 241],
#   'fczpp-PvlGA_120': [1, 301],
#   'fdc15cp7xCE_035': [1, 251],
#   'gisafTmbVd8_158': [1, 502],
#   'hlfUrVFsGI4_250': [1, 241],
#   'i97J1c943LY_013': [1, 251],
#   'iBHdHkdFPaU_031': [1, 251],
#   'iPvhbZR0vos_106': [1, 301],
#   'ivcEbuMdhB0_020': [1, 241],
#   'jrEmJ70wfwg_011': [1, 251],
#   'k0BgxtFZkoM_019': [1, 301],
#   'knNGmAH2TPU_040': [1, 251],
#   'ksyM6Zw9gZw_115': [1, 301],
#   'lJBJeXA4gmw_005': [1, 301],
#   'n4hMHNodJbU_035': [1, 251],
#   'nTWZ1GSdVdI_025': [1, 301],
#   'naH68eSm2H4_202': [1, 251],
#   'o_Z3AFKHxSc_045': [1, 251],
#   'ofdFj_giGWU_048': [1, 251],
#   'ohzSBLMohAY_032': [1, 301],
#   'pNcsbZax_OI_015': [1, 251],
#   'pT2h5WiJ7Qc_140': [1, 301],
#   'q0htEqpnKUE_053': [1, 301],
#   'qO5wMN-ZC_s_028': [1, 241],
#   'rSOFI1misJg_035': [1, 301],
#   'skOY_OHA_KM_018': [1, 301],
#   't_R8Bazi0RI_041': [1, 301],
#   'tpuZ3vTfnds_029': [1, 301],
#   'u9wHHV9byRg_048': [1, 241],
#   'uUGsLoZYXb4_025': [1, 251],
#   'u_z2Tsoa2iE_039': [1, 301],
#   'ugH_5g1ZMWw_108': [1, 301],
#   'wzf8DqjdyA0_348': [1, 251],
#   'x_txHMDll-g_034': [1, 301],
#   'yPLicFeGOck_113': [1, 301],
#   'ylsMMsla6M0_012': [1, 241],
#   'ynp0pfUMRtE_032': [1, 301]},
#  'quickstep': {'0uIleIL978o_040': [1, 301],
#   '1Qx_0ws2wMM_025': [1, 301],
#   '3AegrylWJ_g_010': [1, 301],
#   '7XrJM8C_yZ0_013': [1, 301],
#   '7s4akPdwH7k_012': [1, 301],
#   '82b98BJ07eQ_005': [1, 301],
#   '84oDmFB2uyk_020': [1, 301],
#   '9cWWK2IO9NY_042': [1, 301],
#   '9xLsInICoHo_049': [1, 301],
#   'AEr037iBrzw_027': [1, 301],
#   'AdDiNkilWpk_011': [1, 301],
#   'BcWyfmhkuVE_034': [1, 301],
#   'BkP8sDddMsU_027': [1, 301],
#   'BrqQ6IZT4MA_008': [1, 241],
#   'C-RLbGv39dc_133': [1, 251],
#   'DDm7nPWT2ec_018': [1, 301],
#   'DPmMJ1KTE3c_001': [1, 251],
#   'DydCrso0PJo_003': [1, 301],
#   'EnVSdYSJ28A_117': [1, 301],
#   'FcKMOnNK3Lw_002': [1, 301],
#   'G6NLXj0NebQ_040': [1, 301],
#   'GLrPe8ybF_Y_238': [1, 241],
#   'GNOwDih_nsk_011': [1, 301],
#   'IqkDYzkBExw_048': [1, 301],
#   'Jh_9kZLCjac_018': [1, 301],
#   'L43rbQi29zU_007': [1, 301],
#   'LAsXeh5SOUY_010': [1, 301],
#   'M2QA2pW6KMc_223': [1, 301],
#   'MAJVSTIVuDM_020': [1, 251],
#   'N1bRdiWnijM_1310': [1, 301],
#   'NmfDHiMLk58_024': [1, 301],
#   'OXn0x66Y65s_027': [1, 301],
#   'Oga6RxeUVIo_007': [1, 301],
#   'OrKpF6T0NRM_047': [1, 301],
#   'POwmphhvuzo_058': [1, 301],
#   'PQ8BM4HpqKI_015': [1, 301],
#   'Pi4G088ptBk_046': [1, 301],
#   'Q349svhKxz8_010': [1, 301],
#   'QDiPQ7uBYY4_734': [1, 301],
#   'RMw_7Bs6d8A_038': [1, 301],
#   'Rqs-3N_fl5w_022': [1, 301],
#   'SnMaWq-Q1_E_023': [1, 301],
#   'Ss98tBS_AbQ_029': [1, 251],
#   'V3oy-SXMZds_749': [1, 301],
#   'Wz7NdK9oGZg_034': [1, 301],
#   'X22sCJ-xXJ4_059': [1, 301],
#   'X53uafpmFgM_043': [1, 301],
#   'Y94TgeL0m0s_036': [1, 301],
#   'Ybapt7P96wI_137': [1, 301],
#   'Yc3p4_WGhUU_006': [1, 301],
#   '_0PbUDDUKSE_027': [1, 251],
#   '_6YXgJATdVU_044': [1, 301],
#   '_YnwZjcA3X0_024': [1, 251],
#   '_pqgtFqtg40_555': [1, 301],
#   'cC_U9ZwCUpE_031': [1, 301],
#   'dihHypWDsDo_012': [1, 301],
#   'dnLulUvGFaA_015': [1, 301],
#   'e7vE2jdmXbc_007': [1, 301],
#   'eEKSBowT_GA_059': [1, 301],
#   'fINnVBdfIRY_010': [1, 301],
#   'jPDdURT1aYo_057': [1, 251],
#   'kxDdXUiRnYA_040': [1, 301],
#   'lbI2jqpOWX4_029': [1, 241],
#   'lnoviCi2y_I_017': [1, 301],
#   'mBt-cEgqPwc_221': [1, 301],
#   'miLlSSRxRTU_019': [1, 301],
#   'o9YtSG6CsG0_136': [1, 241],
#   'oGvby4hi9BQ_020': [1, 301],
#   'pVUVp87SuMg_031': [1, 301],
#   'pW2GDCViUUg_022': [1, 301],
#   'qsnE4HGvLs8_006': [1, 301],
#   'sQHdqKnRweY_004': [1, 301],
#   'sm91ToMRUnU_052': [1, 301],
#   'tAf1J7nWlxI_006': [1, 301],
#   'u1XLmia4wa8_011': [1, 301],
#   'uQMh8N3Ug5g_040': [1, 301],
#   'uQqUNZS7OK4_011': [1, 301],
#   'uhRby2yJSb4_059': [1, 301],
#   'vT7dR72319I_045': [1, 301],
#   'y7ZoQYgtJVg_158': [1, 251],
#   'zQho9w1Rpvw_010': [1, 301],
#   'zUp1K5UTqKA_206': [1, 301]},
#  'foxtrot': {'02WOiWd3Z-0_052': [1, 301],
#   '0b7Ste-L190_015': [1, 301],
#   '1vp_bZZW_sE_035': [1, 301],
#   '2EvK7EwOqzg_122': [1, 301],
#   '3gHTdEa6gF4_100': [1, 301],
#   '3zCT36UnEcA_405': [1, 301],
#   '5e_n5JJR0g4_008': [1, 301],
#   '64Jt_xi7FeA_014': [1, 301],
#   '6HMAc69RRx0_047': [1, 241],
#   '7TOfxC4UzSQ_042': [1, 301],
#   '8uMn7XUF36s_025': [1, 301],
#   '99oWaQPa7tc_140': [1, 301],
#   'AHFfvSoFeCk_046': [1, 251],
#   'AdRl3japXJ4_057': [1, 301],
#   'CCdE5dwl5Ms_029': [1, 301],
#   'Cug_H_G1-Ic_040': [1, 301],
#   'DuX-R1KgEck_527': [1, 301],
#   'DyTgd4NvH38_026': [1, 301],
#   'E4Wl4T2LJ9A_523': [1, 251],
#   'EUGKVmN0DOU_021': [1, 301],
#   'FQ6Pj0LQUS8_038': [1, 301],
#   'FVGTLEK69I4_055': [1, 301],
#   'FeXlMzVFfF4_032': [1, 301],
#   'HEaSQfRw2No_004': [1, 301],
#   'HJyQjQy9n-U_350': [1, 301],
#   'Md0gzA2n_Mc_006': [1, 301],
#   'MtZ8hm_sFh4_057': [1, 301],
#   'Ng1Qeu-2RQU_120': [1, 301],
#   'Qjopi9GICbM_051': [1, 301],
#   'QqM6lXluCMw_023': [1, 301],
#   'RQpaRC_McSI_424': [1, 301],
#   'RXhQUuudi9g_054': [1, 301],
#   'RjsDHJanp-g_035': [1, 301],
#   'SK1GA0NcsxM_057': [1, 301],
#   'SzWNayeS-K8_424': [1, 301],
#   'TFVX_ekWkDw_057': [1, 301],
#   'TKD_iUDUKDw_007': [1, 301],
#   'UOLfJpdwBBI_024': [1, 301],
#   'UadTF1J_vHs_016': [1, 301],
#   'Ui9uy6dRKMs_115': [1, 301],
#   'VKx8OMf_j5Y_012': [1, 301],
#   'WJaKRTWufco_014': [1, 301],
#   'X4xHzqdq0gE_056': [1, 301],
#   'XR_Hwtfz5s4_018': [1, 602],
#   'Ybapt7P96wI_506': [1, 301],
#   'ZA--9Yr-2KI_017': [1, 301],
#   '_3o3zsW1FIQ_112': [1, 301],
#   '_7VGPSwZCzY_033': [1, 301],
#   'bABNTwURPCw_030': [1, 301],
#   'c4swTn068xQ_033': [1, 301],
#   'cZ93eIDzYIA_017': [1, 301],
#   'ezbpkmExW30_035': [1, 301],
#   'fNJqZkDpcfA_049': [1, 251],
#   'fg3Wqr8DzSQ_024': [1, 301],
#   'frTrXsUoro8_013': [1, 301],
#   'gCY_AXdJVl8_055': [1, 301],
#   'gVqYJYD8dnE_049': [1, 301],
#   'gsrmD35K4VI_005': [1, 301],
#   'h4LfkNTCJjM_015': [1, 301],
#   'hpsOUaUYnfk_037': [1, 301],
#   'j_GUMFIzaII_047': [1, 301],
#   'jiq6UZyXK44_015': [1, 301],
#   'kQtAMqHke30_043': [1, 301],
#   'keelWKQGWIs_030': [1, 301],
#   'lvlsR0Sb9o0_015': [1, 301],
#   'mr9EKFO3giI_009': [1, 301],
#   'pW65l9g4kyk_011': [1, 301],
#   'q75QSh9M5OI_033': [1, 301],
#   'qjoE7tMdUzQ_016': [1, 301],
#   'rUAH9ctjzaA_012': [1, 241],
#   'rUAH9ctjzaA_014': [1, 241],
#   's6JDqc44Hyo_005': [1, 301],
#   'sFqXe2oMBRM_037': [1, 301],
#   'sRAgy-3S9BY_411': [1, 301],
#   't4xg5_yabdU_015': [1, 301],
#   'uDU9WN2GrSY_015': [1, 301],
#   'uiAsItFDBsk_516': [1, 301],
#   'wzIocD6QAqg_016': [1, 301],
#   'xyQdrpHtrqw_022': [1, 301]},
#  'pasodoble': {'-0VmXQA-RaU_032': [1, 301],
#   '-cry9v7ImO8_634': [1, 241],
#   '149H8vWSbFY_837': [1, 251],
#   '1dQd_4dBtEA_027': [1, 301],
#   '1p7Zm9CRgrI_021': [1, 251],
#   '3H-C31pl8E4_025': [1, 301],
#   '5eYXpS_UHh8_011': [1, 251],
#   '5eYXpS_UHh8_054': [1, 251],
#   '6UYQWmufctc_014': [1, 301],
#   '6_5ctcQYVCE_055': [1, 251],
#   '6_98feSGkRE_024': [1, 251],
#   '7Bjqi6FjqLE_1014': [1, 251],
#   '7K5O-kCME1A_036': [1, 301],
#   '7n4c69nTYeo_028': [1, 251],
#   '9vtnyIbOfrs_106': [1, 251],
#   'A01yN785Yvs_019': [1, 251],
#   'BB-LFcIP6QE_029': [1, 251],
#   'BUW9yKaDIxo_034': [1, 268],
#   'CFh5Dt3PQQo_1240': [1, 251],
#   'DWZ8QiyHE7E_745': [1, 251],
#   'Dx-d6LbKoGU_649': [1, 251],
#   'FS8nYPbxjwI_028': [1, 251],
#   'H54n3Dt-6XA_118': [1, 251],
#   'HMyTAmCwwSY_022': [1, 241],
#   'HknJUs3gPuE_631': [1, 241],
#   'JAZXRG2fA28_046': [1, 301],
#   'KQFWVbC2NqM_018': [1, 251],
#   'LXwOIHJJ7a0_751': [1, 251],
#   'ML3n5d4Wvac_020': [1, 301],
#   'Nk9LlrQDVQY_053': [1, 301],
#   'ORZQ8I28zAQ_103': [1, 301],
#   'OmsD5qv6uPE_751': [1, 251],
#   'Q-Nd4GAU5KU_115': [1, 251],
#   'QwyLQ1KqQoE_055': [1, 241],
#   'R-fUo934xpI_043': [1, 301],
#   'S0a5eQgr94w_909': [1, 251],
#   'S18L1ybX3f8_014': [1, 301],
#   'S18L1ybX3f8_035': [1, 301],
#   'SH2ZkjsLpqM_104': [1, 251],
#   'SZ2OfdtzFiQ_541': [1, 301],
#   'TGvyix_esxo_411': [1, 251],
#   'UDMX-EX8fM0_024': [1, 241],
#   'UteCuS0GlCE_050': [1, 241],
#   'V2no3-aznok_047': [1, 251],
#   'YNkXsZ98DkI_003': [1, 301],
#   'YUV2U6IC6Hs_053': [1, 251],
#   'YWUrqxfHihk_048': [1, 301],
#   'Z7xo0G0I2hE_655': [1, 251],
#   'Z8u3yFRt9WA_125': [1, 301],
#   'ZUYn7wpRtII_027': [1, 251],
#   '_aUEUq49gF4_050': [1, 251],
#   '_v6nTrYbiB8_1258': [1, 251],
#   'a2UussWxF_o_020': [1, 241],
#   'a63SJK07FbM_1314': [1, 251],
#   'd3ew2Sx43uw_051': [1, 251],
#   'eJN2uMf9Vl8_032': [1, 251],
#   'eW9HwmFu3Zs_1400': [1, 502],
#   'eocVi71fGuQ_054': [1, 301],
#   'fQKwpeg0dOM_005': [1, 301],
#   'fiaNUmKiBTQ_1350': [1, 251],
#   'ftq0WWSr-fs_047': [1, 301],
#   'fu6rZUtnMVw_039': [1, 241],
#   'ggNNqhwDrWk_903': [1, 251],
#   'h31TDg4uoAE_010': [1, 241],
#   'hBC-EzG8_xg_034': [1, 251],
#   'hCCxHSofNbU_126': [1, 241],
#   'hNrzgJ_cCBo_027': [1, 301],
#   'hmB5nfkCeb8_1507': [1, 251],
#   'jFD9V8lGM0A_008': [1, 301],
#   'kI5qKE4JTA8_738': [1, 251],
#   'lJ8WOqwqkkE_059': [1, 301],
#   'lJ8WOqwqkkE_103': [1, 301],
#   'mdRV47lryJk_028': [1, 251],
#   'n0vPhMswb1g_026': [1, 241],
#   'nUBVpQR-uuk_040': [1, 241],
#   'o-eI9VskcaM_108': [1, 251],
#   'oTChqAW5ZK4_033': [1, 251],
#   'obT2bO9qh9Q_230': [1, 241],
#   'p8RVRrj1f7Q_028': [1, 301],
#   'pCFwh1fPWHM_110': [1, 301],
#   'pNcwTMVExr0_052': [1, 241],
#   'peC22IsBDQw_023': [1, 301],
#   'pigr3J7sefY_041': [1, 241],
#   'r3C-a8k3WsQ_104': [1, 251],
#   'rZBImFtLhxA_047': [1, 301],
#   'tG0YSlUaOmU_029': [1, 241],
#   'tGNPzBEDo_I_722': [1, 251],
#   'tJjn9Tz5htw_049': [1, 301],
#   'tK4urv9uIIU_104': [1, 251],
#   'ui2IS3XCamw_2234': [1, 502],
#   'w2cHAwG2vpc_042': [1, 301],
#   'wjSPL1th5oY_1410': [1, 251],
#   'xawoNnLz3MU_041': [1, 251],
#   'xn3HzlblLAo_738': [1, 251],
#   'y5PUxFENRqY_105': [1, 301],
#   'yRGVgNEE5VY_2125': [1, 301],
#   'yShShty0SJg_054': [1, 301],
#   'zpWOSeu3OZc_055': [1, 301]},
#  'tap': {'-ZxOm8B-BX4_020': [1, 502],
#   '0k3u23ml_eQ_059': [1, 301],
#   '1BpMnODNrlQ_036': [1, 301],
#   '1MxLu0PisK4_019': [1, 502],
#   '268L4qbfxyA_028': [1, 301],
#   '2TU7dE_9Vi4_341': [1, 241],
#   '3N77MyEBMFQ_010': [1, 301],
#   '3ZeVevTdyvA_102': [1, 301],
#   '3aD-5BINJu8_038': [1, 301],
#   '4d7dQ2fRoHw_047': [1, 301],
#   '5xxTkB5bGy4_046': [1, 251],
#   '69KkUQy0dO4_037': [1, 301],
#   '7Tftcimjo5o_210': [1, 301],
#   '8Ns5jSPsqYU_131': [1, 301],
#   '90I4Vh4G3sM_036': [1, 301],
#   '9PcSNa38lps_134': [1, 301],
#   'AG5StoMM7o0_051': [1, 301],
#   'BEZH9oZJnzU_149': [1, 244],
#   'BdIXFjOOEL4_047': [1, 502],
#   'CTTslr6yacQ_100': [1, 301],
#   'D1ZYhVpdXbQ_227': [1, 251],
#   'DRBRjEMIyEc_051': [1, 251],
#   'DzXHpxlf85U_023': [1, 301],
#   'FkUCYlr7r44_044': [1, 301],
#   'FnHsi2yZLs4_047': [1, 301],
#   'GB2yiIoEtXw_147': [1, 241],
#   'GLaZR_CZNbw_155': [1, 241],
#   'GbGmaCatT_k_152': [1, 301],
#   'HE35eV2pDv4_048': [1, 301],
#   'ISeCp56ud4I_056': [1, 301],
#   'IteILIXjDcA_037': [1, 602],
#   'JIcQe0iFX3w_044': [1, 241],
#   'KBeyu2HBkag_045': [1, 301],
#   'LAU8eBek_NU_031': [1, 301],
#   'Lc7tCSUm3AQ_055': [1, 502],
#   'MPW-geOjDG4_246': [1, 241],
#   'MZ-6MPSt9DI_110': [1, 241],
#   'NjjS29lAwf0_027': [1, 248],
#   'OAfHveS6cMw_052': [1, 151],
#   'OG11vNqwsSM_142': [1, 251],
#   'P2S5CAFiZik_005': [1, 301],
#   'Q4FYNF02yEM_059': [1, 301],
#   'Qgk62UJsdjQ_000': [1, 241],
#   'Rl88sW_rtv0_115': [1, 301],
#   'SEbD8j_c7Uo_128': [1, 241],
#   'SkSp4EKatnI_018': [1, 241],
#   'T1MXCjyVDzc_135': [1, 301],
#   'T7ZQAZX8ynU_110': [1, 502],
#   'U3ee8IXNq8I_131': [1, 502],
#   'UGPc3w5t2yU_020': [1, 241],
#   'UdOKGR7MqIM_010': [1, 241],
#   'VI84LYNQdqM_036': [1, 301],
#   'VVQ0JFzXMgY_320': [1, 301],
#   'WiEF1bHmJr8_006': [1, 301],
#   'WxA6OgucAcM_220': [1, 241],
#   'YctI_K2-KCY_026': [1, 251],
#   'YotMwwixPsw_106': [1, 251],
#   '_Y2eap41d6k_048': [1, 301],
#   'cUrs9z5VcJE_051': [1, 301],
#   'dNTkPcdAXks_037': [1, 301],
#   'dOw42fsEfWY_033': [1, 301],
#   'defiAaVw8Jw_143': [1, 301],
#   'fZyX1EKddK8_002': [1, 241],
#   'g-1RbT7J_rE_021': [1, 301],
#   'gel8aSLHoWY_042': [1, 241],
#   'h_YEzyEkj_0_018': [1, 301],
#   'hzNRlVa2bUA_021': [1, 251],
#   'iHQ5WiJF_Mw_033': [1, 301],
#   'k9edXWpg64E_002': [1, 241],
#   'kLbEsKyH7tA_029': [1, 301],
#   'kZkekwrnbqw_055': [1, 251],
#   'kiS_5Cw-4CM_114': [1, 251],
#   'lCEHVql6qVM_112': [1, 502],
#   'lm1OzvPJg30_112': [1, 301],
#   'mawLpga0pn8_002': [1, 241],
#   'mg0skqqSGAs_127': [1, 301],
#   'np4Qt-Ma_vg_001': [1, 291],
#   'o6fseiCsRA4_202': [1, 301],
#   'oEW3JOzgu_Q_023': [1, 251],
#   'pkjkCpq-tnM_002': [1, 301],
#   'pvU2dc95mjk_017': [1, 301],
#   'qHYD9R_r4Ro_017': [1, 301],
#   'quV72bV2nMs_205': [1, 251],
#   'sLkh5DPaGFs_038': [1, 301],
#   'tPsr32TXMzQ_044': [1, 301],
#   'tZcbwz3N2eU_033': [1, 241],
#   'uBzxB0j9Vbs_032': [1, 301],
#   'uOx2y_xXtiY_007': [1, 301],
#   'vdekANqz1mk_051': [1, 502],
#   'wYpKU87nPYM_125': [1, 241],
#   'xz2V44lQlqA_035': [1, 301],
#   'yEsVpv0c8TE_025': [1, 301],
#   'yRrDlXD1w58_201': [1, 241],
#   'zkz7AeJDZ54_013': [1, 301],
#   'zyuDzF8JRUM_029': [1, 301]},
#  'samba': {'-7NLcoVA9SU_045': [1, 251],
#   '-7w_wiSXR3g_016': [1, 251],
#   '-cry9v7ImO8_025': [1, 241],
#   '08hJ2pbtNVY_035': [1, 151],
#   '1e7EDPldTuw_157': [1, 251],
#   '2QKy6XonGcI_035': [1, 251],
#   '3oEjr90Oiew_032': [1, 502],
#   '3sMjgFKqi4E_020': [1, 301],
#   '49jzvT2R-2k_108': [1, 241],
#   '6_hqpOxaln8_027': [1, 301],
#   '6xG8Ci6kEsU_030': [1, 301],
#   '7Bjqi6FjqLE_356': [1, 251],
#   '7KPSus6RW4E_039': [1, 251],
#   '7huId5_C4MM_110': [1, 241],
#   '8GxZoulM_N0_030': [1, 301],
#   '8hBuhzxf4JY_040': [1, 251],
#   '8nY6fyXdlJY_100': [1, 251],
#   '8oya5vVKbzw_039': [1, 301],
#   'AoOS1o-r_bs_033': [1, 251],
#   'B6eRMhFCyII_052': [1, 251],
#   'CFh5Dt3PQQo_034': [1, 251],
#   'CSsgYejx6n8_030': [1, 196],
#   'CdLQ0f9NBQQ_002': [1, 301],
#   'Clez1pjv50Y_106': [1, 251],
#   'DWZ8QiyHE7E_309': [1, 251],
#   'Dx-d6LbKoGU_035': [1, 251],
#   'Eysv-ad4sWg_023': [1, 251],
#   'F9K43n1wVsA_011': [1, 301],
#   'GIXFY4zdNAM_022': [1, 241],
#   'GbgwLHXYXFY_016': [1, 251],
#   'Gf6FWjPp4Dw_037': [1, 301],
#   'HTYNyxsQhAw_016': [1, 241],
#   'HUXxfHVNfwY_028': [1, 251],
#   'HknJUs3gPuE_014': [1, 106],
#   'Iu1EY027hSw_252': [1, 251],
#   'JOqgZovNNpE_024': [1, 251],
#   'JrzgGQlEVZo_012': [1, 251],
#   'KZtjb-r2GsM_012': [1, 219],
#   'KoyIHRbKQHc_017': [1, 241],
#   'Lb-LLPO0aIs_026': [1, 251],
#   'LdCS4aUYRzM_116': [1, 251],
#   'MjkwHqwank0_042': [1, 502],
#   'NjIuTO7m2p8_027': [1, 251],
#   'OQLdXQ6d1s4_305': [1, 251],
#   'OYEHcB32gpk_024': [1, 251],
#   'OmsD5qv6uPE_039': [1, 251],
#   'PGGmSlCZctU_038': [1, 502],
#   'PRTb7nsD2kw_040': [1, 251],
#   'S0a5eQgr94w_442': [1, 251],
#   'SZ2OfdtzFiQ_028': [1, 301],
#   'TMf3baM35K0_026': [1, 251],
#   'UuHG1C0l0SM_130': [1, 251],
#   'UvqkTgdi53E_130': [1, 251],
#   'VGIds6mSKdo_103': [1, 301],
#   'VOAW9PVoCFk_009': [1, 251],
#   'WJl3UqLrRqI_028': [1, 251],
#   'XDqBJIXMSPg_049': [1, 251],
#   'XWgCxcuAZz0_031': [1, 251],
#   'YPsX3NKrWZI_020': [1, 251],
#   'YcvHq7kn9lA_043': [1, 251],
#   'Yk32mUWrsAQ_032': [1, 251],
#   'Z4e2G3_BBvo_030': [1, 207],
#   'ZD0e__WDsMU_015': [1, 251],
#   'ZoD96eXRXDw_012': [1, 241],
#   '_HF8AZ88wnk_220': [1, 301],
#   '_ik3V_WD-6A_051': [1, 251],
#   '_v6nTrYbiB8_156': [1, 251],
#   'bXw47HHh-zI_015': [1, 241],
#   'cF3usGUzXh0_036': [1, 241],
#   'cKKigfzoQCY_028': [1, 251],
#   'dtU8mCSp2RE_302': [1, 251],
#   'e07OoQH7I0o_014': [1, 251],
#   'e76aqQuVV7o_042': [1, 301],
#   'ehndKwt-Rqk_035': [1, 241],
#   'ej_wdFU0duk_103': [1, 251],
#   'fiaNUmKiBTQ_457': [1, 251],
#   'fiaNUmKiBTQ_716': [1, 251],
#   'ggNNqhwDrWk_437': [1, 251],
#   'gvKSEem0Ogc_017': [1, 241],
#   'jcq-I4Y3_xk_059': [1, 251],
#   'kElD2DiRt2g_022': [1, 251],
#   'kI5qKE4JTA8_255': [1, 251],
#   'lm6-Mq4_9W8_016': [1, 301],
#   'n-8r880oKr0_132': [1, 251],
#   'n4sI4AzXTjk_028': [1, 301],
#   'pnFQrNf2Vzg_019': [1, 301],
#   'qy1vXzdQj4Q_011': [1, 301],
#   'rePZB7B5_2M_050': [1, 251],
#   'rqutokxEg34_044': [1, 301],
#   'tBJO6-FRXmE_024': [1, 251],
#   'tGNPzBEDo_I_318': [1, 251],
#   'tQy92Afrllk_042': [1, 301],
#   'ui2IS3XCamw_1205': [1, 502],
#   'wjSPL1th5oY_040': [1, 251],
#   'xn3HzlblLAo_102': [1, 251],
#   'yFLtUPr_IC4_033': [1, 251],
#   'yRGVgNEE5VY_1132': [1, 301]},
#  'flamenco': {'--u1fww3vgs_048': [1, 301],
#   '-2v52ne80Qo_244': [1, 301],
#   '0W9fybHUSOs_110': [1, 301],
#   '1QU5CyYPVp4_047': [1, 301],
#   '2PrH_ygx6IM_052': [1, 271],
#   '2Y1bQIZY1Vc_055': [1, 301],
#   '2mMpm2xzMMk_535': [1, 301],
#   '4CKtLabIApE_049': [1, 251],
#   '4g4nNGjbpwY_157': [1, 301],
#   '4hbhkIWSX-Q_353': [1, 251],
#   '7L4zXJ1OS6c_456': [1, 301],
#   '7WMyWRlkGIY_1022': [1, 251],
#   '97w_mvV7C9U_520': [1, 251],
#   '9OJT3GebUgg_148': [1, 301],
#   '9U5TNavFpF4_004': [1, 301],
#   '9Y2gICFe9mQ_007': [1, 301],
#   '9YJWZDncb3c_124': [1, 301],
#   '9lVv2RBLesk_029': [1, 301],
#   'AoCgCJyOj2g_007': [1, 301],
#   'BDDt4eRpTf8_248': [1, 251],
#   'BOONaTPqPJc_044': [1, 251],
#   'ChELLaEZ0Do_123': [1, 251],
#   'D88FTGscSuU_038': [1, 602],
#   'DFRTTIKF2As_058': [1, 251],
#   'DMmaQqzrn9o_008': [1, 301],
#   'DT14gNCLg_U_351': [1, 301],
#   'E0wfw6UJiRw_2058': [1, 301],
#   'EZWEk2Crh34_105': [1, 301],
#   'Ejb9LwpNSlg_148': [1, 301],
#   'F-VKHmIG_XQ_037': [1, 301],
#   'GPb56EW4908_1019': [1, 301],
#   'HWWfDV9w2S4_255': [1, 301],
#   'ICfjEsFNYtA_106': [1, 301],
#   'JQz_Bn8mRsg_540': [1, 251],
#   'JUFYLyzfgKs_255': [1, 251],
#   'K5igX8ehx0c_053': [1, 251],
#   'KHEBs58npvA_034': [1, 502],
#   'N3ieIRBoDDQ_028': [1, 251],
#   'NacCLcjuMFc_027': [1, 251],
#   'NacCLcjuMFc_141': [1, 251],
#   'NacCLcjuMFc_308': [1, 251],
#   'OTm2Wk2Tx1I_026': [1, 301],
#   'Ozptnm4zbQY_139': [1, 251],
#   'PyY3yFlTDbo_314': [1, 301],
#   'SY6Vy9tKW3U_327': [1, 251],
#   'SjfklrNFJY4_110': [1, 299],
#   'VOqaphuiQug_003': [1, 301],
#   'Ve5so61pDkM_1351': [1, 251],
#   'W6_7IG7C3Vk_052': [1, 301],
#   'Wy5nqf_WeWk_210': [1, 301],
#   'XNhfV_53W7A_030': [1, 251],
#   'Y4rqfXgJPjw_255': [1, 301],
#   'YHUvzU_qqSY_017': [1, 301],
#   'YSTCsA5vZNo_025': [1, 251],
#   'YZ6G_bRGWVo_029': [1, 301],
#   'YfzplJh_XaY_036': [1, 301],
#   'ZPQYIQ1UyeE_1021': [1, 241],
#   'ZPQYIQ1UyeE_318': [1, 241],
#   '_NCUDuR-DTY_018': [1, 251],
#   'aRWpnbCWkg0_220': [1, 251],
#   'dhpCY8XXvmo_2846': [1, 301],
#   'dqyItsY-yck_034': [1, 251],
#   'f43C2MIIEzU_330': [1, 251],
#   'fEqazI4eezQ_216': [1, 301],
#   'fgN2mMFqjxg_031': [1, 251],
#   'gDvmpIMA64k_106': [1, 251],
#   'gc1HCoFIyKs_024': [1, 241],
#   'gxzU5EqNL14_054': [1, 241],
#   'hEK-ACY2BF0_059': [1, 251],
#   'iZo6BpEv9TQ_358': [1, 251],
#   'ijRrDHeAcTg_021': [1, 301],
#   'jWCY2isbkC4_021': [1, 201],
#   'mTUbT8zx1lo_007': [1, 301],
#   'n-0W4gb3jEI_045': [1, 251],
#   'n2GQohU77Y4_114': [1, 251],
#   'nbCzkiRwqvY_053': [1, 251],
#   'oBI01Tnrvhs_008': [1, 301],
#   'odFAoWNhULU_004': [1, 301],
#   'pNGXaNMyA1o_037': [1, 301],
#   'pfrrAgguA1U_145': [1, 251],
#   'ptxn0UPUILU_047': [1, 301],
#   'qAm4z2EJjQU_100': [1, 251],
#   'qdUX0erlDqM_202': [1, 301],
#   'sLFH01qJT3k_037': [1, 298],
#   'u7yJ0ChjtxQ_037': [1, 241],
#   'veswUKSXkdc_505': [1, 251],
#   'y3x9c9bh9Mc_143': [1, 251],
#   'zxSyQ-K6Jh0_147': [1, 251]},
#  'ballet': {'-5Yp-vToI2E_016': [1, 241],
#   '-sEgjXxjxIw_102': [1, 145],
#   '0aUhNK8tJPU_035': [1, 241],
#   '0cTtPWmpGdc_023': [1, 241],
#   '1hdHc1hJAWU_005': [1, 251],
#   '2OcaeW67VIc_030': [1, 301],
#   '2SMmL6kIx-w_053': [1, 226],
#   '3iTBHVeUDgo_021': [1, 251],
#   '3xjpYjLO1aM_030': [1, 301],
#   '44CFZ1pz_SM_020': [1, 241],
#   '57bRsLf6Ph4_015': [1, 251],
#   '9QTYNnEraLY_030': [1, 145],
#   '9VJRYKIP67s_010': [1, 301],
#   '9VhxpHgPTy8_005': [1, 251],
#   '9WvQamsXuqI_050': [1, 241],
#   '9ZNFPk60yjE_232': [1, 301],
#   'Acc5akNgImA_010': [1, 251],
#   'B-DUOlHKKVU_005': [1, 251],
#   'BVM8AP3luyI_015': [1, 251],
#   'CNh2kHhY29Q_141': [1, 251],
#   'D0Va5IvHVws_010': [1, 301],
#   'Fo250jmBl6I_005': [1, 251],
#   'H50e7FgcsQE_033': [1, 251],
#   'HEM5cG_43vo_500': [1, 241],
#   'H_Vq7JnN3cA_046': [1, 241],
#   'HfBiMFgM5vU_049': [1, 301],
#   'HwvyKmpTEkg_120': [1, 301],
#   'J9iXXoigZs8_520': [1, 251],
#   'KAfPbrhGKcU_120': [1, 251],
#   'LoigxYt5Hgk_122': [1, 301],
#   'LuKekvgdkiE_130': [1, 193],
#   'MUct7h3dxyo_010': [1, 251],
#   'MaV7CwS-qoE_208': [1, 251],
#   'MaV7CwS-qoE_712': [1, 251],
#   'ONY1CO6KEhQ_020': [1, 241],
#   'OZ97W_rRGiQ_647': [1, 251],
#   'Q_CIBonze5I_038': [1, 251],
#   'QnArX3S4AQ4_100': [1, 301],
#   'S5HwZJQ8NuA_011': [1, 251],
#   'SmRrfm1ihGg_008': [1, 241],
#   'T4Q3OLE491U_117': [1, 176],
#   'W6Hxyg5pnSA_028': [1, 251],
#   'WQO4Asq5YRE_157': [1, 251],
#   'WaZnAyXsX4k_010': [1, 251],
#   'Wz_f9B4pPtg_020': [1, 301],
#   'XAsMB3eRe6g_007': [1, 251],
#   'XQ2g5NXq0QI_246': [1, 251],
#   'Xj1_aETg6Ww_640': [1, 251],
#   'XwmwsGT8IQ4_510': [1, 121],
#   'cIFB-GmLGyQ_024': [1, 301],
#   'cIFB-GmLGyQ_210': [1, 301],
#   'cIFB-GmLGyQ_227': [1, 301],
#   'cw8YnWs4wp8_022': [1, 301],
#   'cw8YnWs4wp8_117': [1, 301],
#   'dQxppJjk_rA_030': [1, 301],
#   'evLmJCDBn14_032': [1, 101],
#   'fYmTBeUxjC8_133': [1, 241],
#   'gREJlNlEhRU_100': [1, 301],
#   'hAQs_rlyCKo_148': [1, 201],
#   'hBo-SPFhCJY_140': [1, 301],
#   'hfzAXUkzlMo_014': [1, 251],
#   'hkOijGdD6jo_037': [1, 301],
#   'hqOmSVMgoG0_428': [1, 126],
#   'i1hR3-DVlR0_115': [1, 251],
#   'kbcIHzKyVI0_102': [1, 251],
#   'kuc7EyfDRrI_200': [1, 251],
#   'l2pHvQZu9ek_036': [1, 301],
#   'm4A6PLeGIB4_005': [1, 251],
#   'mQMMXBv7hYo_017': [1, 251],
#   'mSvNjhEPh7I_050': [1, 201],
#   'mZYD8mCS5Vc_307': [1, 251],
#   'mZYD8mCS5Vc_720': [1, 251],
#   'nM-rm68GyRk_020': [1, 301],
#   'nQxihx9WU_k_002': [1, 301],
#   'nh5ecxfjYBk_033': [1, 251],
#   'o1eV2Mgc_BI_018': [1, 126],
#   'omzg05Sa494_101': [1, 251],
#   'pBAY_XH3sgw_010': [1, 251],
#   'pflQ0M6hGtc_233': [1, 151],
#   'pg5IJeXW6cw_010': [1, 301],
#   'ql3o-1eSdbQ_145': [1, 251],
#   'rDnJ8JlPieU_421': [1, 251],
#   'rd1SDbQbHvM_010': [1, 301],
#   'tX0gxJTGBKM_110': [1, 301],
#   'u--jDp2Hieg_131': [1, 251],
#   'vrXQ8uAnipo_021': [1, 181],
#   'zI9oB_oCRlc_020': [1, 301],
#   'zPQp-Re-PlA_235': [1, 301],
#   'zWBVa2m_4Fs_050': [1, 251]},
#  'rumba': {'-Odo8mDqt8k_042': [1, 301],
#   '-cry9v7ImO8_414': [1, 241],
#   '0EB76fW-Pso_107': [1, 251],
#   '0hXdHkxT6zk_114': [1, 241],
#   '0kYux71ndqM_009': [1, 301],
#   '10Vh5JJ32ks_025': [1, 241],
#   '1yJUgYNl6yY_052': [1, 301],
#   '2uDf0T01saw_015': [1, 251],
#   '3AD6kE4cQSg_025': [1, 251],
#   '3lgWQJpz-ZM_044': [1, 251],
#   '4-qRIyou-2U_010': [1, 301],
#   '4LLD8_3BHw4_012': [1, 301],
#   '4i3wqwI40js_023': [1, 241],
#   '5_lRr4nRa4w_033': [1, 251],
#   '6MlvQlkjHj8_022': [1, 301],
#   '6ZA1_ToVVoA_039': [1, 251],
#   'AimsuobIC3U_120': [1, 301],
#   'AtEdu658plw_008': [1, 301],
#   'Bi1JnR4mYAs_017': [1, 301],
#   'CRBDM68Q1_g_010': [1, 301],
#   'CVjHICNGCPM_225': [1, 301],
#   'E-5ttEAqxX0_007': [1, 301],
#   'EKKjENK2FWs_055': [1, 301],
#   'F90-L5SFONE_026': [1, 301],
#   'FQYeMIzE40k_034': [1, 301],
#   'GZmaUoUrSWg_100': [1, 301],
#   'Gl8TGBVWfsE_106': [1, 301],
#   'HVYkiBRe-vk_028': [1, 251],
#   'HknJUs3gPuE_359': [1, 241],
#   'Hx-3xGDhzV8_028': [1, 301],
#   'IZ13fZbpJzU_022': [1, 301],
#   'J4iZs6qkq54_036': [1, 301],
#   'KWN0dHzUGP4_025': [1, 602],
#   'MhhHEsmeOy8_015': [1, 301],
#   'N7HyayG8uzQ_048': [1, 301],
#   'NG_nxIfZ91o_012': [1, 301],
#   'PHMJ74fdqVc_010': [1, 301],
#   'PolZ7ngquHE_015': [1, 301],
#   'PqagOrN6HdU_022': [1, 251],
#   'QIvPo14UVkc_007': [1, 301],
#   'R8dwN1_Npho_019': [1, 301],
#   'SZ2OfdtzFiQ_446': [1, 301],
#   'TENR4qT66pM_020': [1, 301],
#   'US0lEYJQCJ4_011': [1, 301],
#   'UU1yPSpPmUk_049': [1, 301],
#   'UcUb-W5Qyzs_046': [1, 301],
#   'Ul1EZw7M78U_006': [1, 301],
#   'VCPQ4q1_AmE_008': [1, 301],
#   'VKMSRWoaJKU_205': [1, 301],
#   'WD-tfNxXeWw_017': [1, 241],
#   'WXFeltoub2U_034': [1, 301],
#   'Waxr0RvB-_k_017': [1, 301],
#   'WhJ2Ljc_MX0_129': [1, 251],
#   'WreUUX3zlBY_045': [1, 301],
#   'XS6s71pfBPQ_119': [1, 301],
#   'XoUH3WeYu_M_238': [1, 301],
#   'YcKXzXjNi7w_037': [1, 301],
#   'ZbvGCDoqUJw_040': [1, 251],
#   '_v6nTrYbiB8_853': [1, 251],
#   '_x-rYJ7iwLA_005': [1, 301],
#   'a41fSGgMMaw_018': [1, 301],
#   'akb3CJ56Dv0_044': [1, 241],
#   'bNRzZvWKWbs_026': [1, 301],
#   'bkepCy7P6tQ_028': [1, 301],
#   'cE76ghvZ4ns_030': [1, 251],
#   'e48oXGnj6mE_013': [1, 301],
#   'eVRbQFgBkts_022': [1, 301],
#   'ecuwcl8EIeU_059': [1, 301],
#   'edoQlG3NTLY_015': [1, 241],
#   'esh4kwOAnrs_019': [1, 301],
#   'g5D27IQnBFI_037': [1, 251],
#   'gHKzWCvsEvs_026': [1, 251],
#   'gxR3VfT9EA4_003': [1, 301],
#   'h3hvqvL1kZ4_053': [1, 301],
#   'iaIwMGkk5kY_036': [1, 301],
#   'ihk7bZwTIlo_014': [1, 301],
#   'ixvrsdppMsk_035': [1, 301],
#   'mXheNYNTfkE_045': [1, 251],
#   'nJMu5a_eN6Q_051': [1, 301],
#   'pUZSvYHGHls_011': [1, 301],
#   'q1O9Qu2_fY4_050': [1, 301],
#   'qxTaZQXmd_U_032': [1, 301],
#   'rOts7OtbBiU_015': [1, 301],
#   'rQmRJFC00xg_715': [1, 251],
#   'tSAsvmhM3eY_017': [1, 301],
#   'tfFLHVg4rjQ_014': [1, 301],
#   'tjeUiuPI2Vk_010': [1, 301],
#   'uKE-UnXbnL0_036': [1, 301],
#   'uOCke9290fs_049': [1, 301],
#   'uVxKdOO8FnQ_046': [1, 301],
#   'uXJD4RlO1B8_043': [1, 301],
#   'wfZRT40TkO4_023': [1, 301],
#   'wn0fw_NvdB0_035': [1, 251],
#   'xg-qSlKNpl0_300': [1, 301]},
#  'waltz': {'-0J3ddQVBZs_016': [1, 301],
#   '-1R5_n5Y72Q_017': [1, 301],
#   '-2W1PfHleRM_033': [1, 301],
#   '1V02jRprvoI_015': [1, 301],
#   '2-SpbbnIlBE_008': [1, 301],
#   '3T-3aM3gvew_033': [1, 301],
#   '3zCT36UnEcA_005': [1, 301],
#   '9f3V5rHGKiE_027': [1, 301],
#   'AQ-izQC-S1Y_031': [1, 301],
#   'AQmHJlhUhes_022': [1, 301],
#   'AdRl3japXJ4_309': [1, 301],
#   'CgnxSOnzYsY_049': [1, 301],
#   'DCAFALb8dEY_103': [1, 301],
#   'DrLPmyGCALw_035': [1, 301],
#   'DuX-R1KgEck_019': [1, 301],
#   'EAWAJlNKiCc_105': [1, 301],
#   'Ed2_IC1v3v0_053': [1, 301],
#   'EsMh7imAMNU_054': [1, 301],
#   'FAQcrMBcr-U_030': [1, 301],
#   'HJyQjQy9n-U_100': [1, 301],
#   'HJyQjQy9n-U_535': [1, 301],
#   'HJyQjQy9n-U_640': [1, 301],
#   'HLOCzfW0yjc_011': [1, 301],
#   'I-F5Bve3Mmo_016': [1, 301],
#   'Ig0iqE7_-3I_030': [1, 301],
#   'JQQ-tZFe1fc_105': [1, 301],
#   'K4dYy6SJMwk_009': [1, 301],
#   'K7M1tOTH_qE_104': [1, 301],
#   'LqJA0iYLqi0_039': [1, 301],
#   'MDky47JdBS0_007': [1, 301],
#   'MDky47JdBS0_047': [1, 301],
#   'N1bRdiWnijM_015': [1, 301],
#   'N1bRdiWnijM_1530': [1, 301],
#   'NfaWhm4Ds2Y_055': [1, 301],
#   'OaXTcWA3A1Q_014': [1, 301],
#   'PXiw8DH5JV4_040': [1, 301],
#   'RdDop_W4SBM_013': [1, 301],
#   'RfeFZcXfuls_014': [1, 301],
#   'Ybapt7P96wI_029': [1, 301],
#   'Ybapt7P96wI_757': [1, 301],
#   '_U7jIGZ7z-I_044': [1, 301],
#   '_tC4-7YSCU8_030': [1, 301],
#   'azWcLosbIVY_105': [1, 602],
#   'bR0cPcAwEiI_033': [1, 301],
#   'djL040jEDqU_013': [1, 301],
#   'e9b7MPhyzjU_005': [1, 301],
#   'eJDTz-5BDEI_111': [1, 301],
#   'g9MJ5rPvASI_008': [1, 301],
#   'hNZ875Eibnk_053': [1, 301],
#   'heUmbkFfPWw_043': [1, 301],
#   'idfz0WFk-eE_039': [1, 301],
#   'iqRzOOb94KM_100': [1, 301],
#   'jd2dAmWNSyc_043': [1, 301],
#   'm3YhZOACYqI_018': [1, 301],
#   'mMe-15n-EwU_010': [1, 301],
#   'mWEhW3gomw8_029': [1, 301],
#   'mctigkPYN_c_026': [1, 301],
#   'nUAQQvxSfXQ_048': [1, 301],
#   'nuWL11X_wjk_023': [1, 301],
#   'oikcRADJbDc_036': [1, 301],
#   'q-78v5_Cpgg_020': [1, 301],
#   'q-kL4TPjOcQ_015': [1, 301],
#   'qN2xDAiX23g_022': [1, 301],
#   'qTuBDM63KbA_034': [1, 301],
#   'qrwE0ttonjc_008': [1, 301],
#   'rMyANjgKrUo_059': [1, 301],
#   'sPGNU2pZ-mo_103': [1, 301],
#   'sRAgy-3S9BY_616': [1, 301],
#   'sRAgy-3S9BY_710': [1, 301],
#   'tfuAZbCz4uY_014': [1, 301],
#   'uD04eVdLXQo_003': [1, 301],
#   'ui0LwWviGeM_041': [1, 301],
#   'uiAsItFDBsk_010': [1, 301],
#   'uiAsItFDBsk_626': [1, 301],
#   'vsXvdbDmwsw_015': [1, 301],
#   'xXWPf8wnhdo_033': [1, 301],
#   'z3MsbUfJrf8_040': [1, 301],
#   'z49Scf6Eud4_016': [1, 301],
#   'zUp1K5UTqKA_042': [1, 301],
#   'zchjlpArkDw_009': [1, 301]},
#  'cha': {'-0VmXQA-RaU_020': [1, 301],
#   '-AXfEN_LJl4_011': [1, 301],
#   '-FonsHg9utw_030': [1, 301],
#   '-cry9v7ImO8_227': [1, 241],
#   '08rWdLdm3Vk_035': [1, 301],
#   '2GASA28cpck_010': [1, 301],
#   '2z1XaOZMhjk_008': [1, 301],
#   '3KKxhwwnL0o_014': [1, 241],
#   '3ZMH4j0Hqv0_033': [1, 301],
#   '6L6wnpUhERU_055': [1, 301],
#   '6_hqpOxaln8_228': [1, 301],
#   '75Ano5ECzY8_105': [1, 301],
#   '7W23ObHLOhU_023': [1, 251],
#   '8YUtjpq4-Rk_030': [1, 301],
#   '8xjwxvhswFY_030': [1, 301],
#   '9WsRWIQQcX0_013': [1, 301],
#   '9grDHvFCWyA_015': [1, 301],
#   '9tyZsswHOvg_049': [1, 301],
#   'AOZBvBfOQ7k_025': [1, 251],
#   'AV8y1PNmrTg_110': [1, 251],
#   'A_-r5iWVDA8_038': [1, 251],
#   'Ah15ipJWdvU_046': [1, 251],
#   'CVjHICNGCPM_030': [1, 301],
#   'CwJx9eEdo54_049': [1, 251],
#   'E_QKLaXcCtg_020': [1, 301],
#   'FfDBLaGM98M_112': [1, 301],
#   'HQ8QeZ5n11M_030': [1, 251],
#   'HVmF305EYrU_006': [1, 301],
#   'HknJUs3gPuE_214': [1, 241],
#   'IHCHZJdd2JU_052': [1, 241],
#   'JQ2deSrahFE_056': [1, 301],
#   'KmZ4B0eAMWI_028': [1, 301],
#   'MKYVJBLsNic_021': [1, 301],
#   'MPeJFpNr_VA_012': [1, 301],
#   'MvAmH5vMjn0_014': [1, 301],
#   'NvO83ppc64g_020': [1, 251],
#   'PZdJVUQrem4_107': [1, 301],
#   'P_gLEeL4DMw_012': [1, 301],
#   'Pk1RfQvobxE_100': [1, 301],
#   'Q9b7vleZd9w_001': [1, 301],
#   'S3Q1EiTV9xA_030': [1, 251],
#   'SZ2OfdtzFiQ_221': [1, 301],
#   'T2FEGwZjKwU_022': [1, 301],
#   'TS7htE1OZIs_020': [1, 301],
#   'UKPNpi1E4oU_023': [1, 301],
#   'VEeLT-RTCiM_035': [1, 301],
#   'VKMSRWoaJKU_032': [1, 301],
#   'Vl0rLfBGGXE_025': [1, 301],
#   'XoUH3WeYu_M_024': [1, 301],
#   'YIGpnkYy0kI_014': [1, 301],
#   'Z9MhFtJt6Ms_029': [1, 301],
#   'ZWA-UElshb0_008': [1, 301],
#   '_IcQeIX1eeo_017': [1, 301],
#   '_emKFNoDOds_034': [1, 301],
#   '_v6nTrYbiB8_713': [1, 251],
#   'a_0u1FAFVdQ_021': [1, 301],
#   'bz_Ngw5HVpc_033': [1, 251],
#   'cMjGFQhekYY_024': [1, 301],
#   'd5nqrwVcGWE_031': [1, 301],
#   'e4iO6a8Lm0E_013': [1, 301],
#   'eEiLUAR7HkY_046': [1, 301],
#   'fZzo6PyX92Y_017': [1, 251],
#   'fbuqzxlwvb0_029': [1, 301],
#   'gY1r5v7mmFs_119': [1, 301],
#   'gmu-P4XwEvE_105': [1, 301],
#   'h0bOlYBrBDw_121': [1, 251],
#   'hXUzdjMl6rE_031': [1, 241],
#   'hxbapfGTxts_004': [1, 301],
#   'i2H1zHJYp2E_036': [1, 301],
#   'iPoRhkFFMmg_043': [1, 301],
#   'itLtuJhn1vg_040': [1, 301],
#   'k2CnX-BULJk_026': [1, 301],
#   'kIgmXQXqIDQ_022': [1, 251],
#   'kR108huzV_E_036': [1, 301],
#   'lVQrGyrQ8P8_105': [1, 301],
#   'm2TthjT6Ox8_026': [1, 251],
#   'maIGRIgL7Xo_019': [1, 301],
#   'o8M5tBaRvuI_232': [1, 301],
#   'oHQVemRh1Uw_030': [1, 301],
#   'oZVopYD1ocQ_117': [1, 301],
#   'omhpzSsaU0w_029': [1, 251],
#   'q0qwdpZdN_g_014': [1, 251],
#   'rvQI4GmLrTs_018': [1, 251],
#   'sKiXFaH0UPc_016': [1, 301],
#   'u94WC6aWGLU_056': [1, 301],
#   'uDEJtsBliTE_104': [1, 301],
#   'uzkaV1xapFc_118': [1, 301],
#   'v9PFlYnlkj0_031': [1, 301],
#   'vO7FB594eiw_033': [1, 251],
#   'vVPUkd5FNk4_047': [1, 251],
#   'wTzM1AvV-94_011': [1, 301],
#   'wYITeXKYFHw_016': [1, 251],
#   'xg-qSlKNpl0_007': [1, 301],
#   'yABsjxsZxfQ_019': [1, 301],
#   'yzoICR6Z7ns_005': [1, 301],
#   'zFR0eaJrWJs_013': [1, 301],
#   'zJ392rOjAP8_039': [1, 251],
#   'zL5WwP25pog_034': [1, 301]},
#  'latin': {'01f-oLGZv1s_017': [1, 251],
#   '0x3vmRT-ZhY_115': [1, 301],
#   '3Q-gQAuS4e8_129': [1, 241],
#   '3nd8WQy58Pw_850': [1, 251],
#   '3tST-Vz4Mx8_115': [1, 301],
#   '4U13C3huAm8_043': [1, 241],
#   '5HbFic9gDgg_033': [1, 301],
#   '8CFGxVhwU8A_041': [1, 251],
#   '8qAGcFpaUlc_032': [1, 301],
#   '92xEvnbR-uQ_1310': [1, 301],
#   '9euAmqQ2Ap4_110': [1, 301],
#   'ACzxHHCEgNs_029': [1, 150],
#   'AXBYpYohb1Q_227': [1, 226],
#   'CU4fkMrgTLk_115': [1, 301],
#   'Cm0rzK9KHJA_034': [1, 251],
#   'Dqefwy1sgAI_030': [1, 301],
#   'HQnYvmAgQTY_029': [1, 211],
#   'Hq1tAsV-3II_051': [1, 251],
#   'II-D-6srbOo_041': [1, 241],
#   'JoeT_kH7xK0_030': [1, 301],
#   'KK7DfjF8ZbY_029': [1, 241],
#   'KMAbhuNIJ_s_117': [1, 251],
#   'KmEIHmEQOr0_048': [1, 241],
#   'LROmVrFdlzE_040': [1, 301],
#   'NMHCFuwFJI4_125': [1, 301],
#   'ORhLk4CErFs_010': [1, 241],
#   'OVI0tBDQ-6g_108': [1, 301],
#   'OpRAmD1bHVI_036': [1, 301],
#   'PHKbDso1VsA_030': [1, 241],
#   'PZ767hTMs4I_120': [1, 301],
#   'QmL0QYsctV0_030': [1, 251],
#   'RKUqbv5EEoU_114': [1, 301],
#   'RRLNRSUNrl0_103': [1, 241],
#   'Tiy6xhcBU4k_021': [1, 301],
#   'Tz7eGxzEM3Q_044': [1, 251],
#   'Wtjfwu3SDvE_230': [1, 301],
#   'X02JMkquGkg_230': [1, 125],
#   'XC-ZAGwnmJI_832': [1, 301],
#   'Y1v-k8TLN8A_048': [1, 241],
#   'YO-4NRov2e0_034': [1, 301],
#   'YjgSQDvMNBc_030': [1, 301],
#   'YnjwNIfcOeU_043': [1, 251],
#   'ZEq54f1q0Xs_100': [1, 301],
#   '_530Y1Him7s_232': [1, 301],
#   'aKOChOei2JQ_050': [1, 301],
#   'b9-Td5NiE8Y_110': [1, 301],
#   'bOFgpzWobbU_050': [1, 241],
#   'd4K8ZOXeFjo_200': [1, 251],
#   'dmcaNDqMwRM_050': [1, 301],
#   'dq6x7cvEJdM_040': [1, 241],
#   'epWiSNsGPYc_121': [1, 241],
#   'gJyBIr-IgSU_230': [1, 301],
#   'giI99WoMc2E_005': [1, 251],
#   'heJXZdT-ne0_358': [1, 301],
#   'iRntFnMArIU_206': [1, 301],
#   'is9wrZ0ShZU_322': [1, 251],
#   'kIcCU3B9-mo_107': [1, 301],
#   'lTYM8MYjRDc_047': [1, 251],
#   'lVfseUfniWc_014': [1, 301],
#   'lWfg9CNg-uE_123': [1, 301],
#   'm5n4rHetyiU_039': [1, 301],
#   'm7nvjCIAm1U_056': [1, 301],
#   'nIIVfIRsMnA_100': [1, 301],
#   'p0jKdU6cgOk_027': [1, 251],
#   'pItP-nK-VcA_032': [1, 298],
#   'q-ENUJyPyrY_130': [1, 241],
#   'qMqOGvDaAT4_042': [1, 301],
#   'qdVg1ptQC1w_147': [1, 301],
#   'r5X_IkhkquU_040': [1, 251],
#   'rtUKt8afl0I_043': [1, 241],
#   'sGqeSEarG0I_1301': [1, 251],
#   'sW9TOGfrs8c_202': [1, 251],
#   'sW9TOGfrs8c_253': [1, 251],
#   't5GNJd-uLyM_050': [1, 301],
#   'tUr25oHoslU_024': [1, 301],
#   'tftX2rlfs1g_050': [1, 301],
#   'thE7aztQF4Q_109': [1, 241],
#   'thh6s51PjT4_1040': [1, 246],
#   'u1ZCTSdlujY_230': [1, 241],
#   'u9JAvVmJA9A_050': [1, 241],
#   'uiZcWuUBjHQ_105': [1, 251],
#   'uiZcWuUBjHQ_220': [1, 251],
#   'utXOH66L21o_030': [1, 301],
#   'v0eF7UhEW-A_055': [1, 301],
#   'w2K4A-d1bC4_036': [1, 301],
#   'xIT4YI4n-0A_040': [1, 301],
#   'xoDVJXvjrfE_006': [1, 301],
#   'xoDVJXvjrfE_110': [1, 301],
#   'xuj4II-UI44_054': [1, 241],
#   'zXqNSI2OH8g_153': [1, 301]},
#  'square': {'-CcCpM87vac_138': [1, 301],
#   '-ZAHtJppIXQ_017': [1, 241],
#   '-v31uYwWz7c_050': [1, 241],
#   '-wC1XbWkVZQ_002': [1, 241],
#   '075zOIBxw40_040': [1, 301],
#   '0NAKYTJktHM_146': [1, 301],
#   '0SfLyyGINyA_053': [1, 300],
#   '0x1fVsK_puU_011': [1, 301],
#   '0y_hC4ITwyo_036': [1, 251],
#   '1Tzhb7YFEFA_330': [1, 301],
#   '1vOs_nGs_5w_039': [1, 301],
#   '1xXePOakJGs_215': [1, 181],
#   '2-CGdk8ouCY_234': [1, 301],
#   '2__prgoQl4Q_135': [1, 301],
#   '3Tae97hVs6U_148': [1, 301],
#   '5LFl88f2aio_002': [1, 241],
#   '5UYZ3jsFRJE_053': [1, 301],
#   '6ee0DcgWHjw_125': [1, 301],
#   '6lV-mH_BSGs_204': [1, 301],
#   '6wL2ucm2Wds_133': [1, 301],
#   '7_D4xRURWbw_002': [1, 301],
#   '7_UM0oajDto_036': [1, 301],
#   '8XgiY2Pa4Jc_002': [1, 301],
#   'A3X-mPB2MYQ_004': [1, 241],
#   'AGn_T7u6U2Q_039': [1, 301],
#   'AN1xDUPt9Kw_029': [1, 301],
#   'BeyaJ1GCcaA_205': [1, 301],
#   'CDjIj4vgmvc_008': [1, 151],
#   'CSDAWhFRDEk_203': [1, 241],
#   'CVfCNbFc23Q_007': [1, 301],
#   'EkxRtkhCZl0_102': [1, 301],
#   'F3JwWUzFkm8_140': [1, 241],
#   'FBXNtyL5_fg_100': [1, 301],
#   'FhcTmd5AiuM_131': [1, 301],
#   'G8k8H2GjUIA_030': [1, 251],
#   'GWkfQMQogMQ_006': [1, 301],
#   'GauwbSAA1Ag_100': [1, 241],
#   'GyfPMmX_jj8_059': [1, 301],
#   'HhmzXPipfag_020': [1, 241],
#   'IXPlfZOPtqU_108': [1, 301],
#   'JHqS1bOOLVc_017': [1, 301],
#   'JHqS1bOOLVc_050': [1, 301],
#   'JZoUBW47L3c_015': [1, 301],
#   'JlIzMxNGKe8_140': [1, 241],
#   'L66k9o_7_QU_036': [1, 301],
#   'LWhD1md44gI_006': [1, 301],
#   'NPHJnbCeg7Q_015': [1, 241],
#   'N_cQuBSo_jk_018': [1, 301],
#   'PKmo-1xdRYo_034': [1, 301],
#   'PStj6-3ja6I_108': [1, 251],
#   'PeDx588I6rM_130': [1, 301],
#   'RpbBVHlC8SU_056': [1, 241],
#   'SBfImn_ld4M_010': [1, 301],
#   'SXiIG7dx-gc_036': [1, 301],
#   'Shz1mpjHktw_106': [1, 301],
#   'U3LSAlA4zyw_111': [1, 301],
#   'UMoy_jtBbt4_036': [1, 301],
#   'W8WxxMSpntg_010': [1, 301],
#   'Z9vffJJJfNA_027': [1, 241],
#   'ZFGbV_1YbY8_120': [1, 301],
#   'ZLzBWdBswmY_036': [1, 301],
#   '_5Um2Kjnsm4_150': [1, 301],
#   '_jjx_Z7AmzI_012': [1, 301],
#   '_nX57wzP3Uw_002': [1, 301],
#   'daaj1F1dYGM_033': [1, 301],
#   'eYjNdnSX1vY_103': [1, 301],
#   'fOFYb-r2Cc8_153': [1, 301],
#   'fymBcoVn66M_020': [1, 301],
#   'gGigqJmz_hE_013': [1, 301],
#   'hlbitUpK-38_034': [1, 301],
#   'iDWKh9eFrPo_020': [1, 241],
#   'idiF9-z-5O0_210': [1, 241],
#   'jWQ9N2alkaA_159': [1, 241],
#   'kSNzS9zObCw_002': [1, 301],
#   'mk7l88yKNQo_006': [1, 241],
#   'njttcX9rU7s_044': [1, 301],
#   'o6J9qx2Ixdo_205': [1, 301],
#   'osVt_jfwHps_010': [1, 301],
#   'pPJ6V6L5_mM_032': [1, 241],
#   'ppV-LZBeDko_003': [1, 301],
#   'pqUAtFmQlrE_008': [1, 301],
#   'pxuadJGGYAg_039': [1, 241],
#   'q975LcgLX-E_036': [1, 298],
#   're7ytg0AVAI_020': [1, 301],
#   'rjVWSVA_gWE_150': [1, 241],
#   'tGQCKZRVTio_316': [1, 301],
#   'vJ7axws4kT8_003': [1, 301],
#   'vcfdtkrdtGc_031': [1, 301],
#   'vdtl-b-ZXaI_005': [1, 301],
#   'wYc8Fpi7co4_026': [1, 301],
#   'xH0L8Jcir1A_030': [1, 301],
#   'xVSZB89oGtw_037': [1, 241],
#   'y_SJ7h7U56o_012': [1, 301],
#   'y_jaMF3Vzkc_103': [1, 301],
#   'ylenRKFfP8s_140': [1, 301],
#   'z-ybbyzhrF8_035': [1, 241],
#   'zWi6fadQEkc_036': [1, 301]},
#  'jive': {'-cry9v7ImO8_836': [1, 241],
#   '-yOVSi7JHoY_026': [1, 301],
#   '0V-kTdSgUow_038': [1, 301],
#   '149H8vWSbFY_1016': [1, 251],
#   '1KJXO3pF_cE_013': [1, 301],
#   '1VCCtso_I30_014': [1, 251],
#   '1l_LylqBkrw_010': [1, 301],
#   '1x5CdUQoHBU_100': [1, 251],
#   '2St_nYGhtO0_033': [1, 251],
#   '2fiFzB5bp8E_015': [1, 251],
#   '2fs4E6KHqd8_046': [1, 251],
#   '5y_LQqVdnOM_018': [1, 251],
#   '6SUhxTHwbpE_649': [1, 301],
#   '6xWrBlFSl1w_027': [1, 301],
#   '75t-NIheCho_055': [1, 301],
#   '7Bjqi6FjqLE_1437': [1, 251],
#   '7IJU0c8sNAw_022': [1, 301],
#   '8gUVtMYvJ0E_035': [1, 251],
#   '9UYvOJLTJ6c_023': [1, 251],
#   'AMZh_YPVSjs_051': [1, 251],
#   'CFh5Dt3PQQo_1529': [1, 251],
#   'CIFHrVg_qj8_032': [1, 251],
#   'CSsgYejx6n8_156': [1, 301],
#   'CYkyqjaQGnk_114': [1, 251],
#   'Ci2_wTTEePM_052': [1, 251],
#   'DWZ8QiyHE7E_1129': [1, 251],
#   'DpcNS1qkDtA_029': [1, 251],
#   'FVS-7kfGT18_042': [1, 251],
#   'GdgSd2XEODg_028': [1, 502],
#   'GzfD1EIZwSI_037': [1, 241],
#   'H8TKdPjvjMs_040': [1, 301],
#   'HknJUs3gPuE_804': [1, 241],
#   'JLsNSFRHAu8_027': [1, 251],
#   'Jm7EpSf0c3c_015': [1, 301],
#   'K3aR7iSelgU_007': [1, 241],
#   'LXwOIHJJ7a0_952': [1, 251],
#   'Mn2-AsZaNI4_056': [1, 251],
#   'Mn2-AsZaNI4_646': [1, 251],
#   'N4MaOAEaUkw_058': [1, 301],
#   'N5BbrzLykOc_033': [1, 301],
#   'NxR4Wn2EcfE_024': [1, 251],
#   'OmsD5qv6uPE_936': [1, 251],
#   'S2wwo7q91T0_118': [1, 251],
#   'S2wwo7q91T0_235': [1, 251],
#   'SZ2OfdtzFiQ_732': [1, 301],
#   'SqXiR-A39-Q_024': [1, 301],
#   'ToZ2CEag5ag_021': [1, 301],
#   'TvJ16p9WbBM_116': [1, 241],
#   'Vj8ig_Fgz0c_115': [1, 301],
#   'W1fp_IW3g5w_023': [1, 301],
#   'WXivS2NMb4k_035': [1, 301],
#   'WgqWA69CSzA_023': [1, 251],
#   'XjE9Gpc_jnY_022': [1, 251],
#   'Xr6ss8pZ7fs_009': [1, 301],
#   'XvTGTMK2XYU_013': [1, 301],
#   'Y0Z3JXimxJk_035': [1, 301],
#   'Z7xo0G0I2hE_859': [1, 251],
#   'Z_qO2iBXLvM_021': [1, 251],
#   '_SOL00vts4Y_050': [1, 241],
#   '_v6nTrYbiB8_1657': [1, 251],
#   'a63SJK07FbM_1510': [1, 251],
#   'aB0zKWKZ1fk_016': [1, 251],
#   'ags0RRqfYRI_042': [1, 251],
#   'bACnA7yxxpI_014': [1, 241],
#   'c0gvYNviGx4_022': [1, 241],
#   'cgqWmYXSeRE_009': [1, 251],
#   'cqwUNrZsnhE_038': [1, 241],
#   'e5_mbe_Wn28_044': [1, 301],
#   'eW9HwmFu3Zs_1726': [1, 502],
#   'egXf1tj7qAc_014': [1, 251],
#   'fiaNUmKiBTQ_1630': [1, 251],
#   'g-T_i_dpUPM_144': [1, 251],
#   'gWvz_N76Tag_047': [1, 301],
#   'ggNNqhwDrWk_1222': [1, 251],
#   'hCrnBsJFA0E_012': [1, 251],
#   'hmB5nfkCeb8_1813': [1, 251],
#   'kCQIZnfYPO4_016': [1, 301],
#   'kEr3tAUpyFA_101': [1, 301],
#   'kI5qKE4JTA8_1029': [1, 251],
#   'kit70P94LdE_026': [1, 251],
#   'lwalbME9pKI_106': [1, 241],
#   'm1I4ciF72pM_041': [1, 502],
#   'mMFAmaqmLX0_026': [1, 251],
#   'nFYm2cNWfxs_019': [1, 241],
#   'naPHSdReBBY_052': [1, 241],
#   'ni5xqU1wYx8_023': [1, 251],
#   'oEmta348sQg_024': [1, 251],
#   'q0AajeTRr80_041': [1, 241],
#   'qR7gkLNZsw4_010': [1, 301],
#   'qZYRh9nLSBE_027': [1, 301],
#   'qh8p-zoVRag_038': [1, 251],
#   'rfT8XCcGj_w_010': [1, 241],
#   'tGNPzBEDo_I_910': [1, 251],
#   'tJY7LZmKZ6A_019': [1, 251],
#   'ui2IS3XCamw_2512': [1, 502],
#   'v0ARZ5pW6yo_138': [1, 241],
#   'v3Ckk9NCCJM_059': [1, 241],
#   'vLU-qrH0ft4_030': [1, 251],
#   'w4ViC3SaAds_114': [1, 301],
#   'wMA0TxRsAn0_004': [1, 301],
#   'wjSPL1th5oY_1943': [1, 251],
#   'x7HvaCCi9-U_036': [1, 301],
#   'xg-qSlKNpl0_610': [1, 301],
#   'xn3HzlblLAo_1046': [1, 251],
#   'yRGVgNEE5VY_2942': [1, 301],
#   'y_dFCoUiV54_031': [1, 251]}}

# %%
output = []
for category in index.keys():
    for dance_id in index[category].keys():
        frames = index[category][dance_id][1]
        output.append([category, dance_id, frames])
        
with open('dance-frame-list.json', 'w') as f:
    json.dump(output, f)

# %%
def frames_to_motion(category, dance_id, frames):
    motion = []
    for frame in range(1, frames):
        current_frame_path = "{}{}/{}_{:04d}.json".format(ROOT_DIR, category, dance_id, frame)
        with open(current_frame_path) as f:
            data = json.load(f)
        motion.append(data)
    return motion

# %%
from pathlib import Path

counter = 0
total = len(output)
for d in output:
    [category, dance_id, frames] = d 
    motion = frames_to_motion(category, dance_id, frames)
    dir_path = '../densepose/full/{}'.format(category)
    Path(dir_path).mkdir(parents=True, exist_ok=True)
    with open('{}/{}.json'.format(dir_path, dance_id), 'w') as f:
        json.dump(motion, f)
    counter += 1
    print('{}_{} {}/{}'.format(category, dance_id, counter, total))
# Out:
# tango_-638J1hhteA_019 1/1463
# tango_0-pUvBqZ9PY_105 2/1463
# tango_1yYiYMNxza8_012 3/1463
# tango_3zCT36UnEcA_220 4/1463
# tango_4ZKupt7FxRE_009 5/1463
# tango_4flyoSPVlHI_028 6/1463
# tango_5LxiCFVBuSI_027 7/1463
# tango_8LMvAf5ftZ4_008 8/1463
# tango_8p6MyuvAebg_013 9/1463
# tango_AQ7HEnCtnJg_012 10/1463
# tango_AVaxGhMgHMk_018 11/1463
# tango_AXhCzjiIqRA_043 12/1463
# tango_Ap9Xj0OBgJ8_043 13/1463
# tango_BCIqkUblDpM_026 14/1463
# tango_BvTGEgR2_88_025 15/1463
# tango_DOSiIbjykc4_020 16/1463
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-6344d6b20053> in <module>
#       5 for d in output:
#       6     [category, dance_id, frames] = d
# ----> 7     motion = frames_to_motion(category, dance_id, frames)
#       8     dir_path = '../densepose/full/{}'.format(category)
#       9     Path(dir_path).mkdir(parents=True, exist_ok=True)
#
# <ipython-input-27-7a4c487a3b7f> in frames_to_motion(category, dance_id, frames)
#       4         current_frame_path = "{}{}/{}_{:04d}.json".format(ROOT_DIR, category, dance_id, frame)
#       5         with open(current_frame_path) as f:
# ----> 6             data = json.load(f)
#       7         motion.append(data)
#       8     return motion
#
# /ihome/crc/install/python/anaconda3.6-5.2.0/lib/python3.6/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     294
#     295     """
# --> 296     return loads(fp.read(),
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
#
# ~/.virtualenvs/pytorch/lib/python3.6/codecs.py in decode(self, input, final)
#     316         raise NotImplementedError
#     317
# --> 318     def decode(self, input, final=False):
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
#
# KeyboardInterrupt:
